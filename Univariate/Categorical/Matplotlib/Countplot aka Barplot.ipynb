# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = ['Grad','Postgrad','High','Diploma']
y= [25,42,30,45]

plt.figure(figsize=(7,5))

plt.bar(x,y,color='blue')
plt.xlabel("Categories")
plt.ylabel('Values')
plt.title("Count Plot")
plt.show()
